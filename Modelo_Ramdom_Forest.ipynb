# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# %%
#Definicion base de datos
def df_yf_tidy(

    tickers,

    start=None,

    end=None,

    interval="1d",

    auto_adjust=False,  # Se mantiene False para conservar "Adj Close" y así mantener las 6 columnas

):

    """

    Devuelve un DataFrame 'largo' con múltiples tickers

    Índice por fecha y columna 'Ticker' para identificar.

    """

    cols = ["Open", "High", "Low", "Close", "Adj Close", "Volume"]

    frames = []



    for t in tickers:

        h = yf.Ticker(t).history(

            start=start, end=end, interval=interval, auto_adjust=auto_adjust

        )

        if h.empty:

            continue

        for c in cols:

            if c not in h.columns:

                h[c] = pd.NA

        out = h[cols].copy()

        out["Ticker"] = t

        frames.append(out.reset_index())  # 'Date' pasa a columna



    if not frames:

        return pd.DataFrame(columns=["Date"] + cols + ["Ticker"])



    df = pd.concat(frames, ignore_index=True)

    # Orden de columnas

    df = df[["Date"] + cols + ["Ticker"]]

    return df



#Uso para crear base de datos.

tickers = ["AAPL", "MSFT", "AMZN", "GOOGL", "META"]

df = df_yf_tidy(tickers, start="2000-01-01", end="2025-10-25", interval="1d")




# Variación relativa

df["variacion_relativa"] = df["Adj Close"] / df["Adj Close"].shift(1)

# Variación porcentual (en %)

df["variacion_porcentual"] = (df["Adj Close"].pct_change()) * 100

# Variación logarítmica (en valores decimales)

df["variacion_logaritmica"] = np.log(df["Adj Close"]).diff()

df.tail()
# Out:
#                            Date        Open        High         Low  \
# 28184 2025-10-20 00:00:00-04:00  721.190002  733.770020  720.179993
# 28185 2025-10-21 00:00:00-04:00  736.020020  738.500000  728.750000
# 28186 2025-10-22 00:00:00-04:00  733.830017  740.599976  724.030029
# 28187 2025-10-23 00:00:00-04:00  734.700012  742.409973  733.099976
# 28188 2025-10-24 00:00:00-04:00  736.789978  741.210022  731.150024
#
#             Close   Adj Close   Volume Ticker  variacion_relativa  \
# 28184  732.169983  732.169983  8900200   META            1.021272
# 28185  733.270020  733.270020  7647300   META            1.001502
# 28186  733.409973  733.409973  8734500   META            1.000191
# 28187  734.000000  734.000000  9856000   META            1.000804
# 28188  738.359985  738.359985  9151300   META            1.005940
#
#        variacion_porcentual  variacion_logaritmica
# 28184              2.127155               0.021048
# 28185              0.150243               0.001501
# 28186              0.019086               0.000191
# 28187              0.080450               0.000804
# 28188              0.594003               0.005922

# %%
#Separacion de variables independientes y dependiente
df.dropna(inplace=True)
X = df[['Volume', 'variacion_relativa', 'variacion_porcentual', 'variacion_logaritmica']]
y = df['Adj Close']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
# Modelo base
rf = RandomForestRegressor(random_state=0)
# Mismo espacio de búsqueda, pero muestreado aleatoriamente
param_distributions = {    'n_estimators': [100, 200, 300],    'max_depth': [5, 10, 15],    'min_samples_split': [2, 6, 10],    }
# Random Search (solo probará n_iter combinaciones al azar)
random_search = RandomizedSearchCV(estimator=rf,    param_distributions=param_distributions,    n_iter=30,    cv=5,    scoring='neg_mean_squared_error',    random_state=0,    verbose= 2)
# Entrenar
random_search.fit(X_train, y_train)
print("Mejores parámetros:", random_search.best_params_)
print("Mejor puntaje (MSE negativo):", random_search.best_score_)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 27 is smaller than n_iter=50. Running 27 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=100; total time=   5.9s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=100; total time=   6.7s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=100; total time=   6.5s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=100; total time=   5.8s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=200; total time=  12.3s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=200; total time=  12.3s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=200; total time=  12.3s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=200; total time=  12.3s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=200; total time=  12.7s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=300; total time=  19.5s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=300; total time=  19.0s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=300; total time=  17.7s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=300; total time=  17.9s
# [CV] END .max_depth=5, min_samples_split=2, n_estimators=300; total time=  18.8s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=100; total time=   5.6s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=100; total time=   7.7s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=100; total time=   5.6s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=100; total time=   6.7s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=100; total time=   5.6s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=200; total time=  12.2s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=200; total time=  12.2s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=200; total time=  12.3s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=200; total time=  12.3s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=200; total time=  12.3s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=300; total time=  17.8s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=300; total time=  18.9s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=300; total time=  20.5s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=300; total time=  18.9s
# [CV] END .max_depth=5, min_samples_split=6, n_estimators=300; total time=  17.8s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=100; total time=   6.1s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=100; total time=   6.2s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=100; total time=   5.7s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=100; total time=   6.6s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=100; total time=   5.7s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=200; total time=  12.3s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=200; total time=  12.4s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=200; total time=  12.3s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=200; total time=  12.3s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=200; total time=  12.3s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=300; total time=  17.9s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=300; total time=  18.7s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=300; total time=  17.6s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=300; total time=  18.7s
# [CV] END max_depth=5, min_samples_split=10, n_estimators=300; total time=  17.6s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=  11.0s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=   9.8s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=100; total time=  11.0s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  21.8s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  20.6s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  21.8s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  22.0s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=200; total time=  20.9s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=300; total time=  33.1s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=300; total time=  33.7s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=300; total time=  33.0s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=300; total time=  32.0s
# [CV] END max_depth=10, min_samples_split=2, n_estimators=300; total time=  34.0s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=100; total time=  10.9s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=100; total time=  10.7s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=100; total time=  10.0s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=100; total time=  11.0s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=100; total time=  10.9s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=200; total time=  21.9s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=200; total time=  20.8s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=200; total time=  21.9s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=200; total time=  22.0s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=200; total time=  20.8s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=300; total time=  33.0s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=300; total time=  31.9s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=300; total time=  33.0s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=300; total time=  32.0s
# [CV] END max_depth=10, min_samples_split=6, n_estimators=300; total time=  33.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=  10.2s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=  11.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=  11.1s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=100; total time=  11.0s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  21.4s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  21.5s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  21.9s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  20.9s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=200; total time=  21.9s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=300; total time=  32.9s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=300; total time=  31.9s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=300; total time=  35.0s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=300; total time=  31.9s
# [CV] END max_depth=10, min_samples_split=10, n_estimators=300; total time=  32.5s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=100; total time=  14.9s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=200; total time=  30.0s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=200; total time=  29.9s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=200; total time=  29.4s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=200; total time=  29.7s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=200; total time=  30.5s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=300; total time=  44.1s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=300; total time=  44.5s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=300; total time=  44.8s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=300; total time=  44.3s
# [CV] END max_depth=15, min_samples_split=2, n_estimators=300; total time=  45.2s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=100; total time=  14.4s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=100; total time=  14.4s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=100; total time=  14.4s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=100; total time=  14.5s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=100; total time=  14.4s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=200; total time=  29.2s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=200; total time=  29.4s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=200; total time=  28.8s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=200; total time=  28.9s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=200; total time=  28.8s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=300; total time=  44.3s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=300; total time=  43.1s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=300; total time=  43.2s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=300; total time=  44.5s
# [CV] END max_depth=15, min_samples_split=6, n_estimators=300; total time=  43.1s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=100; total time=  14.2s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=100; total time=  14.2s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=100; total time=  14.2s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=100; total time=  14.4s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=100; total time=  14.8s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=200; total time=  28.7s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=200; total time=  28.5s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=200; total time=  28.4s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=200; total time=  28.5s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=200; total time=  29.0s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=300; total time=  43.0s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=300; total time=  42.6s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=300; total time=  42.5s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=300; total time=  43.9s
# [CV] END max_depth=15, min_samples_split=10, n_estimators=300; total time=  42.5s
# 🔹 Mejores parámetros: {'n_estimators': 300, 'min_samples_split': 10, 'max_depth': 5}
# 🔹 Mejor puntaje (MSE negativo): -6435.412919770245
